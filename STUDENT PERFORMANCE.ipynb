# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("exams.csv")

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group D                some college      standard
# 1    male        group D          associate's degree      standard
# 2  female        group D                some college  free/reduced
# 3    male        group B                some college  free/reduced
# 4  female        group D          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0               completed          59             70             78
# 1                    none          96             93             87
# 2                    none          57             76             77
# 3                    none          70             70             63
# 4                    none          83             85             86

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# - there is no null values in the data

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.describe(include="all").T
# Out:
#                               count unique           top freq    mean  \
# gender                         1000      2          male  508     NaN
# race/ethnicity                 1000      5       group C  323     NaN
# parental level of education    1000      6  some college  224     NaN
# lunch                          1000      2      standard  660     NaN
# test preparation course        1000      2          none  656     NaN
# math score                   1000.0    NaN           NaN  NaN   67.81
# reading score                1000.0    NaN           NaN  NaN  70.382
# writing score                1000.0    NaN           NaN  NaN   69.14
#
#                                    std   min   25%   50%    75%    max
# gender                             NaN   NaN   NaN   NaN    NaN    NaN
# race/ethnicity                     NaN   NaN   NaN   NaN    NaN    NaN
# parental level of education        NaN   NaN   NaN   NaN    NaN    NaN
# ...

# %% [markdown]
# - top students were male
# - group c of race had higher number
# - most of the parents completed their education from some college
# - acoording to the data hope there will be no outliers

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.bar(x=df["gender"].value_counts().index,height=df["gender"].value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                math score  reading score  writing score
# math score       1.000000       0.811767       0.790055
# reading score    0.811767       1.000000       0.948909
# writing score    0.790055       0.948909       1.000000

# %% [markdown]
# - all 3 scores are showing high +ve correlation
# - reading to wrinting score show the highest +ve correlation

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df["lunch"].value_counts()
# Out:
# standard        660
# free/reduced    340
# Name: lunch, dtype: int64

# %%
sns.countplot(data=df,x="lunch")
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %% [markdown]
# - most of the students had std lunch

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df["race/ethnicity"].value_counts()
# Out:
# group C    323
# group D    257
# group B    198
# group E    143
# group A     79
# Name: race/ethnicity, dtype: int64

# %%
sns.countplot(data=df,x="race/ethnicity")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %% [markdown]
# - group c had more number of students followed by group d then b
# - this mainly gives the demographic information about their student
# - it can vary from institution - institution , so need more clear information

# %%
df["total"]=df["math score"]+df["reading score"]+df["writing score"]

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score  total
# ...

# %%
df["average"]=(df["math score"]+df["reading score"]+df["writing score"])/300*100

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 1      male        group D          associate's degree      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 4    female        group D          associate's degree      standard
# ..      ...            ...                         ...           ...
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
df1=df.copy()

# %%
df_grade_top=df[df["average"]>80]

# %%
df_grade_top
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 1      male        group D          associate's degree      standard
# 4    female        group D          associate's degree      standard
# 6    female        group E          associate's degree      standard
# 17   female        group C                 high school      standard
# 18   female        group E          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 979    male        group C            some high school      standard
# 981    male        group E            some high school      standard
# 984  female        group E           bachelor's degree      standard
# 987  female        group D             master's degree      standard
# 994  female        group B          associate's degree      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
sns.countplot(data=df_grade_top,x="parental level of education")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - the students who acquired 80% and above , most of their parents had associate degree or some college degree
# - least students parents in this category had masters
# - there were many parents whose education was only high school
# - we can say that parents education is not a primary criteria for students higher score

# %%
sns.countplot(data=df_grade_top,x="gender")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - female students acquired more marks compared to male

# %%
sns.countplot(data=df_grade_top,x="race/ethnicity")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - group E had higher number of students followed by d and e
# - group A had least number of high grade students

# %%
sns.countplot(data=df_grade_top,x="lunch")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - most students had standard lunch in top graders

# %%
sns.countplot(data=df_grade_top,x="test preparation course")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - more students didnot do any preparation yet grabbed good grades , which tells they will be attentive in class and have higher iq
# - some students completed their prep and grabbed good marks , they had a good tendency to work hard

# %%
df_grade_top.describe(include="all").T
# Out:
#                              count unique                 top freq  \
# gender                         230      2              female  131
# race/ethnicity                 230      5             group E   65
# parental level of education    230      6  associate's degree   60
# lunch                          230      2            standard  198
# test preparation course        230      2                none  121
# math score                   230.0    NaN                 NaN  NaN
# reading score                230.0    NaN                 NaN  NaN
# writing score                230.0    NaN                 NaN  NaN
# total                        230.0    NaN                 NaN  NaN
# average                      230.0    NaN                 NaN  NaN
#
#                                    mean        std        min     25%  \
# gender                              NaN        NaN        NaN     NaN
# race/ethnicity                      NaN        NaN        NaN     NaN
# ...

# %%
df_full=df[df["total"]==300]

# %%
df_full
# Out:
#     gender race/ethnicity parental level of education     lunch  \
# 378   male        group D           bachelor's degree  standard
# 857   male        group E           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score  total  \
# 378               completed         100            100            100    300
# 857               completed         100            100            100    300
#
#      average
# 378    100.0
# 857    100.0

# %% [markdown]
# - there were only two male students who got full marks

# %%
df_low=df[df["average"]<=40]

# %%
df_low
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 33   female        group D             master's degree  free/reduced
# 65   female        group B          associate's degree  free/reduced
# 72   female        group C            some high school      standard
# 228    male        group C                 high school  free/reduced
# 254    male        group D           bachelor's degree      standard
# 276  female        group D             master's degree      standard
# 278    male        group A          associate's degree      standard
# 376    male        group C                 high school      standard
# 468    male        group B            some high school  free/reduced
# 480  female        group C                 high school      standard
# 492  female        group D            some high school      standard
# 513  female        group C          associate's degree  free/reduced
# 561  female        group C          associate's degree  free/reduced
# ...

# %%
df_low_50=df[df["average"]<=50]

# %%
df_low_50
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 15     male        group E             master's degree  free/reduced
# 16   female        group C                some college  free/reduced
# 33   female        group D             master's degree  free/reduced
# 40     male        group C          associate's degree  free/reduced
# 65   female        group B          associate's degree  free/reduced
# ..      ...            ...                         ...           ...
# 967    male        group C            some high school      standard
# 975    male        group E            some high school  free/reduced
# 982    male        group C            some high school      standard
# 988    male        group D            some high school      standard
# 999    male        group D                 high school      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
df[df["average"]<=20]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 228   male        group C                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  total  \
# 228                    none          20             25             15     60
#
#      average
# 228     20.0

# %% [markdown]
# - compared to the data students with less than 40% was less
# - 102 students were having 50% and below
# - most of them scored marks more than 50% which tells us the teachers and students are working good
# - just one out of 1000 students have failed

# %%
df["test preparation course"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='test preparation course'>

# %% [markdown]
# - according the above graph most students was passed without preparation

# %%
df_grade_bet=df[(df["average"]>50)&(df['average']<80)]

# %%
df_grade_bet
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group D                some college      standard
# 2    female        group D                some college  free/reduced
# 3      male        group B                some college  free/reduced
# 5      male        group C            some high school      standard
# 7    female        group B            some high school      standard
# ..      ...            ...                         ...           ...
# 993    male        group D            some high school      standard
# 995    male        group C                some college      standard
# 996    male        group C                some college      standard
# 997  female        group A                 high school      standard
# 998    male        group E                 high school      standard
#
#     test preparation course  math score  reading score  writing score  total  \
# ...

# %%
sns.countplot(data=df_grade_bet,x="gender")
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.countplot(data=df_grade_bet,x="race/ethnicity")
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
sns.countplot(data=df_grade_bet,x="parental level of education")
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(data=df_grade_bet,x="lunch")
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %%
sns.histplot(data=df_grade_bet,x="average")
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
sns.histplot(data=df,x="average")
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
## Explore more visualisation
fig,axis=plt.subplots(1,2,figsize=(15,7))
plt.subplot(121)
sns.histplot(data = df,x = 'average' , bins = 30 ,kde = True,color='g')
plt.subplot(122)
sns.histplot(data=df,x='average',bins=30,kde=True,hue='gender')
# Out:
# <Axes: xlabel='average', ylabel='Count'>

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='lunch')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='lunch')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='lunch')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\1843837595.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\1843837595.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\1843837595.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# - std lunch helped students to perfrom well ,be it a male or female

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df,x='average',kde=True,hue='parental level of education')
plt.subplot(142)
sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='parental level of education')
plt.subplot(143)
sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='parental level of education')
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\22046908.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\22046908.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\22046908.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# <Axes: xlabel='average', ylabel='Count'>

# %% [markdown]
# - In general parent's education don't help student perform well in exam.
# - 3rd plot shows that parent's whose education is of associate's degree or master's degree their male child tend to perform well in exam
# - 2nd plot we can see there is no effect of parent's education on female students.

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
ax =sns.histplot(data=df,x='average',kde=True,hue='race/ethnicity')
plt.subplot(142)
ax =sns.histplot(data=df[df.gender=='female'],x='average',kde=True,hue='race/ethnicity')
plt.subplot(143)
ax =sns.histplot(data=df[df.gender=='male'],x='average',kde=True,hue='race/ethnicity')
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\3382513985.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\3382513985.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4756\3382513985.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)

# %% [markdown]
# - Students of `group A and group B tends to perform poorly in exam.
# - Students of group A and group B tends to perform poorly in exam irrespective of whether they are male or female
